# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

file_location = '../Resources/Crime_Data_from_2010_to_Present.csv'
code_location = '../Resources/macrcode.csv'

crime_data = pd.read_csv(file_location)
crime_data.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA   \
# 0    1307355  02/20/2010 12:00:00 AM  02/20/2010 12:00:00 AM      1350     13
# 1   11401303  09/13/2010 12:00:00 AM  09/12/2010 12:00:00 AM        45     14
# 2   70309629  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      1515     13
# 3   90631215  01/05/2010 12:00:00 AM  01/05/2010 12:00:00 AM       150      6
# 4  100100501  01/03/2010 12:00:00 AM  01/02/2010 12:00:00 AM      2100      1
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0     Newton         1385         2     900
# 1    Pacific         1485         2     740
# 2     Newton         1324         2     946
# 3  Hollywood          646         2     900
# 4    Central          176         1     122
#
#                                          Crm Cd Desc  ... Status  \
# 0                           VIOLATION OF COURT ORDER  ...     AA
# 1  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...     IC
# 2                          OTHER MISCELLANEOUS CRIME  ...     IC
# 3                           VIOLATION OF COURT ORDER  ...     IC
# 4                                    RAPE, ATTEMPTED  ...     IC
#
#     Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0  Adult Arrest    900.0      NaN       NaN      NaN
# 1   Invest Cont    740.0      NaN       NaN      NaN
# 2   Invest Cont    946.0      NaN       NaN      NaN
# 3   Invest Cont    900.0    998.0       NaN      NaN
# 4   Invest Cont    122.0      NaN       NaN      NaN
#
#                                   LOCATION                     Cross Street  \
# 0   300 E  GAGE                         AV                              NaN
# 1          SEPULVEDA                    BL  MANCHESTER                   AV
# 2  1300 E  21ST                         ST                              NaN
# 3          CAHUENGA                     BL  HOLLYWOOD                    BL
# 4          8TH                          ST  SAN PEDRO                    ST
#
#        LAT       LON
# 0  33.9825 -118.2695
# 1  33.9599 -118.3962
# 2  34.0224 -118.2524
# 3  34.1016 -118.3295
# 4  34.0387 -118.2488
#
# [5 rows x 28 columns]

# %%
org_crime_data = crime_data.drop(columns=['Crm Cd 1', 'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'Rpt Dist No', 
                             'Part 1-2', 'Status', 'Status Desc', 'LOCATION', 'Cross Street', 'Vict Age',
                                             'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc', 'Weapon Used Cd', 
                                             'Weapon Desc', 'AREA NAME', 'Mocodes'])
clean_data = org_crime_data.rename(columns={'Date Rptd':'date_reported'})

clean_data.head()
# Out:
#        DR_NO           date_reported                DATE OCC  TIME OCC  AREA   \
# 0    1307355  02/20/2010 12:00:00 AM  02/20/2010 12:00:00 AM      1350     13
# 1   11401303  09/13/2010 12:00:00 AM  09/12/2010 12:00:00 AM        45     14
# 2   70309629  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      1515     13
# 3   90631215  01/05/2010 12:00:00 AM  01/05/2010 12:00:00 AM       150      6
# 4  100100501  01/03/2010 12:00:00 AM  01/02/2010 12:00:00 AM      2100      1
#
#    Crm Cd                                        Crm Cd Desc      LAT  \
# 0     900                           VIOLATION OF COURT ORDER  33.9825
# 1     740  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# 588287      11     624                           BATTERY - SIMPLE ASSAULT
# 2030087     20     510                                   VEHICLE - STOLEN
# 1094805      4     420    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# 1754531     20     761                                    BRANDISH WEAPON
# 1592546      5     354                                  THEFT OF IDENTITY
# 1814992      3     440                 THEFT PLAIN - PETTY ($950 & UNDER)
# 801413      19     624                           BATTERY - SIMPLE ASSAULT
# 386567      18     624                           BATTERY - SIMPLE ASSAULT
# 588888      18     930             CRIMINAL THREATS - NO WEAPON DISPLAYED
# 857151       2     230     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 1970563     14     740  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# 651110      13     437                                   RESISTING ARREST
# 1656326      8     341  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...
# 356668      20     331   THEFT FROM MOTOR VEHICLE - GRAND ($400 AND OVER)
# 84780       10     740  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# 800887       1     624                           BATTERY - SIMPLE ASSAULT
# 478122       9     440                 THEFT PLAIN - PETTY ($950 & UNDER)
# 1400084      6     330                              BURGLARY FROM VEHICLE
# 332808      19     440                 THEFT PLAIN - PETTY ($950 & UNDER)
# 1055018      8     815                SEXUAL PENETRATION W/FOREIGN OBJECT
# 573230      13     626                  INTIMATE PARTNER - SIMPLE ASSAULT
# 648413       4     626                  INTIMATE PARTNER - SIMPLE ASSAULT
# 748854       8     341  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...
# 1952420      9     354                                  THEFT OF IDENTITY
# ...        ...     ...                                                ...
# 1704104      1     236              INTIMATE PARTNER - AGGRAVATED ASSAULT
# 424818       9     740  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# 296575       9     330                              BURGLARY FROM VEHICLE
# 194878      21     440                 THEFT PLAIN - PETTY ($950 & UNDER)
# 863562       6     626                  INTIMATE PARTNER - SIMPLE ASSAULT
# 1112961     21     440                 THEFT PLAIN - PETTY ($950 & UNDER)
# 84506       10     623                            BATTERY POLICE (SIMPLE)
# 1076485      5     230     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 2053858     15     330                              BURGLARY FROM VEHICLE
# 780514      13     210                                            ROBBERY
# 482629       7     310                                           BURGLARY
# 938396      18     330                              BURGLARY FROM VEHICLE
# 1092241      1     440                 THEFT PLAIN - PETTY ($950 & UNDER)
# 663104      14     440                 THEFT PLAIN - PETTY ($950 & UNDER)
# 328049       2     210                                            ROBBERY
# 1378870     11     442           SHOPLIFTING - PETTY THEFT ($950 & UNDER)
# 1470502     16     510                                   VEHICLE - STOLEN
# 322129      19     440                 THEFT PLAIN - PETTY ($950 & UNDER)
# 1268245     14     956            LETTERS, LEWD  -  TELEPHONE CALLS, LEWD
# 1635816      3     310                                           BURGLARY
# 351847      10     354                                  THEFT OF IDENTITY
# 875786       5     440                 THEFT PLAIN - PETTY ($950 & UNDER)
# 288002      10     510                                   VEHICLE - STOLEN
# 209126      19     442           SHOPLIFTING - PETTY THEFT ($950 & UNDER)
# 1787631     20     310                                           BURGLARY
# 1004742      5     210                                            ROBBERY
# 1160110      4     440                 THEFT PLAIN - PETTY ($950 & UNDER)
# 381498      15     510                                   VEHICLE - STOLEN
# 1107564      2     354                                  THEFT OF IDENTITY
# 295177      11     740  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
#
#              LAT       LON
# 912682   34.0817 -118.4598
# 1275476  33.9580 -118.2869
# 1315387  34.0473 -118.2976
# 1825345  34.0076 -118.2653
# 931882   34.0454 -118.2466
# 994119   34.2575 -118.4892
# 588287   34.1221 -118.2188
# 2030087  34.0617 -118.3066
# 1094805  34.0755 -118.2104
# 1754531  34.0436 -118.2960
# 1592546  33.7324 -118.2879
# 1814992  34.0268 -118.2753
# 801413   34.2215 -118.4597
# 386567   33.9330 -118.2717
# 588888   33.9438 -118.2739
# 857151   34.0511 -118.2707
# 1970563  33.9890 -118.4623
# 651110   33.9898 -118.2783
# 1656326  34.0626 -118.4491
# 356668   34.0618 -118.2954
# 84780    34.1775 -118.5360
# 800887   34.0437 -118.2652
# 478122   34.1808 -118.4553
# 1400084  34.1069 -118.3283
# 332808   34.2913 -118.4502
# 1055018  34.0889 -118.5325
# 573230   34.0092 -118.2565
# 648413   34.0475 -118.2168
# 748854   34.0449 -118.3866
# 1952420  34.1495 -118.4399
# ...          ...       ...
# 1704104  34.0569 -118.2540
# 424818   34.2030 -118.4280
# 296575   34.1619 -118.4301
# 194878   34.1904 -118.5906
# 863562   34.1016 -118.3417
# 1112961  34.1719 -118.5684
# 84506    34.2170 -118.5034
# 1076485  33.7886 -118.2458
# 2053858  34.1670 -118.3759
# 780514   34.0082 -118.2740
# 482629   34.0558 -118.3298
# 938396   33.9494 -118.2385
# 1092241  34.0495 -118.2494
# 663104   33.9451 -118.4029
# 328049   34.0818 -118.2941
# 1378870  34.1367 -118.2713
# 1470502  34.2446 -118.2709
# 322129   34.2576 -118.4441
# 1268245  34.0049 -118.4206
# 1635816  34.0146 -118.3057
# 351847   34.2157 -118.5273
# 875786   33.8542 -118.2992
# 288002   34.1961 -118.5564
# 209126   34.2216 -118.4488
# 1787631  34.0749 -118.2868
# 1004742  33.8481 -118.3041
# 1160110  34.0900 -118.1790
# 381498   34.1504 -118.4116
# 1107564  34.0658 -118.2814
# 295177   34.1076 -118.1968
#
# [100000 rows x 9 columns]

# %%
year = pd.DatetimeIndex(clean_data['date_reported']).year
year

# %%
clean_data['year'] = year.astype(str)
clean_data.head()

# %%
clean_data['date_reported'] = pd.to_datetime(clean_data['date_reported'])
clean_data['date_reported'].head()

# %%
clean_data.head()

# %%
lon_sample = clean_data[clean_data['LON'].between(-118.2800, -118.2600)]
mid_LA_sample = lon_sample[lon_sample['LAT'].between(34.0000, 34.2000)]
mid_LA_sample.head()

# %%
df_crime_code = pd.DataFrame(mid_LA_sample['Crm Cd'])
mid_LA_sample['Crime Code'] = df_crime_code
mid_LA_sample.head()

# %%
crime_count = 1
mid_LA_sample['Crime Count'] = crime_count
mid_LA_sample.head()

# %%
count_crime = mid_LA_sample.groupby(['Crime Code', 'year', 'date_reported']).sum()
count_crime = count_crime.sort_values(by='date_reported')
count_crime
